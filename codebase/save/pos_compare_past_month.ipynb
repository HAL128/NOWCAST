# %%
from helpers import *

# %%
df = pd.read_csv('../../DATAHUB/1577b043-c0fb-46e7-8eb1-cf678acda511.csv')
df['DATE'] = pd.to_datetime(df['DATE'])

df
# Out:
#             DATE    TICKER  TOTAL_SALES
# 0     2014-01-01      1301     21049027
# 1     2014-02-01      1301     24881772
# 2     2014-03-01      1301     33947832
# 3     2014-04-01      1301     24015019
# 4     2014-05-01      1301     24083923
# ...          ...       ...          ...
# 38594 2025-02-01  unlisted  18841308547
# 38595 2025-03-01  unlisted  20553120960
# 38596 2025-04-01  unlisted  19575731762
# 38597 2025-05-01  unlisted  20236714694
# 38598 2025-06-01  unlisted  20122182586
#
# [38599 rows x 3 columns]

# %%
# データ読み込みとフィルタリング
df_filtered = filter_data_cca(df)

df_filtered
# Out:
# original data: 38599
# filtered data: 35164
#             DATE TICKER  TOTAL_SALES
# 0     2014-01-01   1301     21049027
# 1     2014-02-01   1301     24881772
# 2     2014-03-01   1301     33947832
# 3     2014-04-01   1301     24015019
# 4     2014-05-01   1301     24083923
# ...          ...    ...          ...
# 35159 2014-11-01   9987          149
# 35160 2014-12-01   9987         2524
# 35161 2015-01-01   9987         2824
# 35162 2015-02-01   9987         1322
# 35163 2015-03-01   9987         1341
#
# [35164 rows x 3 columns]

# %%
df_monthly = daily_to_monthly(df_filtered, 'TOTAL_SALES')
df_monthly
# Out:
# original data: 35164
# monthly data: 34918
#          MONTH TICKER  TOTAL_SALES
# 0      2014-01   1301     21049027
# 1      2014-01   1332    166339746
# 2      2014-01   1333    186553299
# 3      2014-01   1352       877436
# 4      2014-01   1379    142479143
# ...        ...    ...          ...
# 34913  2025-05   9260      1683132
# 34914  2025-05   9274       295897
# 34915  2025-05   9305     24617614
# 34916  2025-05   9852      4450302
# 34917  2025-05   9869     38008201
#
# [34918 rows x 3 columns]

# %%
df_yoy = calculate_yoy(df_monthly, 'TOTAL_SALES')
df_yoy
# Out:
# original data: 34918
# yoy data: 31559
#          MONTH TICKER  TOTAL_SALES       YOY
# 3119   2015-01   1301     25254608  1.199799
# 3120   2015-01   1332    173103682  1.040663
# 3121   2015-01   1333    188857371  1.012351
# 3122   2015-01   1352      1636704  1.865326
# 3123   2015-01   1379    125180895  0.878591
# ...        ...    ...          ...       ...
# 34913  2025-05   9260      1683132  1.403733
# 34914  2025-05   9274       295897  0.845036
# 34915  2025-05   9305     24617614  1.299693
# 34916  2025-05   9852      4450302  1.003495
# 34917  2025-05   9869     38008201  1.022125
#
# [31559 rows x 4 columns]

# %%
df_yoy_compare_past_month = compare_to_past_month(df_yoy, 'YOY')
df_yoy_compare_past_month
# Out:
#          MONTH TICKER  TOTAL_SALES       YOY  COMPARE_PAST_1_MONTHS  \
# 20284  2020-08   1301     23878103  0.886802               0.007376
# 20285  2020-08   1332    197841432  1.028172               0.016732
# 20286  2020-08   1333    195299026  1.011046               0.063792
# 20287  2020-08   1352      1315880  0.775672              -0.066659
# 20288  2020-08   1379     95941593  1.091133              -0.087324
# ...        ...    ...          ...       ...                    ...
# 34913  2025-05   9260      1683132  1.403733               0.152883
# 34914  2025-05   9274       295897  0.845036              -0.179000
# 34915  2025-05   9305     24617614  1.299693              -0.904681
# 34916  2025-05   9852      4450302  1.003495              -0.054066
# 34917  2025-05   9869     38008201  1.022125              -0.047728
#
#        COMPARE_PAST_2_MONTHS  COMPARE_PAST_3_MONTHS  COMPARE_PAST_4_MONTHS  \
# 20284               0.003688              -0.002351              -0.030475
# 20285               0.008366               0.036124               0.046498
# 20286               0.031896               0.053484               0.053165
# 20287              -0.033330              -0.011815               0.074357
# 20288              -0.043662              -0.033793              -0.039848
# ...                      ...                    ...                    ...
# 34913               0.076441               0.231617               0.280519
# 34914              -0.089500              -0.111848              -0.095257
# 34915              -0.452340              -0.410747              -0.398951
# 34916              -0.027033              -0.045011              -0.050529
# 34917              -0.023864              -0.035939              -0.035764
#
#        COMPARE_PAST_5_MONTHS  COMPARE_PAST_6_MONTHS  COMPARE_PAST_7_MONTHS  \
# 20284              -0.122646              -0.153294              -0.137436
# 20285               0.030643               0.005942              -0.000360
# 20286               0.017914               0.002181               0.010853
# 20287               0.103883               0.078997               0.045448
# 20288              -0.042918              -0.020623              -0.001291
# ...                      ...                    ...                    ...
# 34913               0.289279               0.298074               0.305625
# 34914              -0.094028              -0.091275              -0.067622
# 34915              -0.534067              -0.635413              -0.703816
# 34916              -0.046852              -0.037187              -0.025566
# 34917              -0.027874              -0.023175              -0.022152
#
#        COMPARE_PAST_8_MONTHS  COMPARE_PAST_9_MONTHS  COMPARE_PAST_10_MONTHS  \
# 20284              -0.134370              -0.121999               -0.107375
# 20285               0.005290               0.010586                0.014560
# 20286               0.026358               0.042811                0.053837
# 20287               0.025391               0.019440               -0.002203
# 20288               0.021799               0.035988                0.048430
# ...                      ...                    ...                     ...
# 34913               0.325719               0.338719                0.289167
# 34914              -0.055111              -0.054428               -0.090754
# 34915              -0.626366              -0.701642               -0.701271
# 34916              -0.039714              -0.038190               -0.045160
# 34917              -0.025053              -0.024273               -0.026795
#
#        COMPARE_PAST_11_MONTHS  COMPARE_PAST_12_MONTHS
# 20284               -0.109193               -0.112171
# 20285                0.018190                0.022184
# 20286                0.062850                0.067709
# 20287               -0.041245               -0.072795
# 20288                0.057575                0.069520
# ...                       ...                     ...
# 34913                0.216582                0.189109
# 34914               -0.124363               -0.165789
# 34915               -0.685704               -0.600555
# 34916               -0.052693               -0.069174
# 34917               -0.023048               -0.022984
#
# [13889 rows x 16 columns]

# %%
# price dataの読み込み
price_data = pd.read_csv('../../DATAHUB/Price_Data/price_data_for_pos.csv')
price_data
# Out:
#           DATE  TICKER        PRICE  DIVIDENDS  MONTHLY_RETURN
# 0      2001-01    1301   935.276245        0.0             NaN
# 1      2001-02    1301  1021.507446        0.0        0.092199
# 2      2001-03    1301   981.708252       30.0       -0.009593
# 3      2001-04    1301  1122.555542        0.0        0.143472
# 4      2001-05    1301   987.307800        0.0       -0.120482
# ...        ...     ...          ...        ...             ...
# 70831  2025-01    9987  4802.027832        0.0        0.023855
# 70832  2025-02    9987  4711.927734        0.0       -0.018763
# 70833  2025-03    9987  4891.137207       50.0        0.048645
# 70834  2025-04    9987  5176.000000        0.0        0.058241
# 70835  2025-05    9987  5313.000000        0.0        0.026468
#
# [70836 rows x 5 columns]

# %%
# percentiles = [10, 25, 40, 100]

multiple_portfolios = create_multiple_portfolios_compare_past_month(df_yoy_compare_past_month, price_data, percentiles=[i for i in range(5, 101, 5)])
multiple_portfolios.to_csv('../data/pos_compare_past_month.csv')
# Out:
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_1_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_2_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_3_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_4_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_5_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_6_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_7_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_8_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_9_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_10_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_11_MONTHS)
# 上位5%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位10%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位15%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位20%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位25%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位30%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位35%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位40%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位45%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位50%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位55%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位60%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位65%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位70%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位75%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位80%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位85%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位90%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位95%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)
# 上位100%のポートフォリオを作成中... (比較期間: COMPARE_PAST_12_MONTHS)

# %%
# set date index
multiple_portfolios.index = pd.to_datetime(multiple_portfolios.index)

# 可視化
plot_portfolio_returns(multiple_portfolios, y_max=3)

# %%
# plot_growth_rate(multiple_portfolios, 'top_20p_compare_past_12_months')

# %%
# パフォーマンス指標計算
print("パフォーマンス指標を計算中...")
performance_metrics = calculate_performance_metrics(multiple_portfolios)

print("\n=== パフォーマンス指標 ===")
print(performance_metrics.round(2))
# Out:
# パフォーマンス指標を計算中...
#
# === パフォーマンス指標 ===
#                                  Total Return (%)  Annual Return (%)  \
# top_5p_compare_past_1_months                79.93              12.92
# top_10p_compare_past_1_months               84.24              13.48
# top_15p_compare_past_1_months               85.86              13.68
# top_20p_compare_past_1_months               96.93              15.05
# top_25p_compare_past_1_months              100.33              15.46
# ...                                           ...                ...
# top_80p_compare_past_12_months              66.52              11.13
# top_85p_compare_past_12_months              62.89              10.62
# top_90p_compare_past_12_months              63.07              10.65
# top_95p_compare_past_12_months              60.59              10.30
# top_100p_compare_past_12_months             61.56              10.43
#
#                                  Monthly Return (%)  Annual Volatility (%)  \
# top_5p_compare_past_1_months                   1.07                  11.71
# top_10p_compare_past_1_months                  1.10                   9.70
# top_15p_compare_past_1_months                  1.10                   8.59
# top_20p_compare_past_1_months                  1.20                   7.75
# top_25p_compare_past_1_months                  1.23                   7.44
# ...                                             ...                    ...
# top_80p_compare_past_12_months                 0.90                   7.20
# top_85p_compare_past_12_months                 0.87                   7.18
# top_90p_compare_past_12_months                 0.87                   7.22
# top_95p_compare_past_12_months                 0.84                   7.18
# top_100p_compare_past_12_months                0.85                   7.30
#
#                                  Monthly Volatility (%)  Sharpe Ratio  \
# top_5p_compare_past_1_months                       3.38          1.10
# top_10p_compare_past_1_months                      2.80          1.39
# top_15p_compare_past_1_months                      2.48          1.59
# top_20p_compare_past_1_months                      2.24          1.94
# top_25p_compare_past_1_months                      2.15          2.08
# ...                                                 ...           ...
# top_80p_compare_past_12_months                     2.08          1.54
# top_85p_compare_past_12_months                     2.07          1.48
# top_90p_compare_past_12_months                     2.08          1.48
# top_95p_compare_past_12_months                     2.07          1.43
# top_100p_compare_past_12_months                    2.11          1.43
#
#                                  Max Drawdown (%)  Win Rate (%)
# top_5p_compare_past_1_months               -15.37         67.24
# top_10p_compare_past_1_months              -12.78         65.52
# top_15p_compare_past_1_months               -9.78         70.69
# top_20p_compare_past_1_months               -7.26         75.86
# top_25p_compare_past_1_months               -7.08         79.31
# ...                                           ...           ...
# top_80p_compare_past_12_months              -8.18         67.24
# top_85p_compare_past_12_months              -8.00         67.24
# top_90p_compare_past_12_months              -8.02         67.24
# top_95p_compare_past_12_months              -7.87         67.24
# top_100p_compare_past_12_months             -7.99         68.97
#
# [240 rows x 8 columns]

# %%
# 月次統計計算
print("\n=== 月次リターンの詳細統計 ===")
monthly_stats = calculate_monthly_statistics(multiple_portfolios)
print(monthly_stats.round(2))
# Out:
# === 月次リターンの詳細統計 ===
#                                  月次平均リターン (%)  月次ボラティリティ (%)  最小月次リターン (%)  \
# top_5p_compare_past_1_months             1.07           3.38         -7.79
# top_10p_compare_past_1_months            1.10           2.80         -6.12
# top_15p_compare_past_1_months            1.10           2.48         -5.15
# top_20p_compare_past_1_months            1.20           2.24         -4.70
# top_25p_compare_past_1_months            1.23           2.15         -4.66
# ...                                       ...            ...           ...
# top_80p_compare_past_12_months           0.90           2.08         -6.40
# top_85p_compare_past_12_months           0.87           2.07         -6.23
# top_90p_compare_past_12_months           0.87           2.08         -6.29
# top_95p_compare_past_12_months           0.84           2.07         -6.18
# top_100p_compare_past_12_months          0.85           2.11         -6.32
#
#                                  最大月次リターン (%)  中央値 (%)
# top_5p_compare_past_1_months            13.17     0.95
# top_10p_compare_past_1_months            7.56     0.90
# top_15p_compare_past_1_months            7.05     1.19
# top_20p_compare_past_1_months            6.61     1.21
# top_25p_compare_past_1_months            6.78     1.29
# ...                                       ...      ...
# top_80p_compare_past_12_months           5.48     1.02
# top_85p_compare_past_12_months           5.37     0.96
# top_90p_compare_past_12_months           5.26     1.00
# top_95p_compare_past_12_months           5.24     0.98
# top_100p_compare_past_12_months          5.34     0.96
#
# [240 rows x 5 columns]

# %%
# 最終累積リターン計算
print("\n=== 最終累積リターン ===")
final_returns = calculate_final_returns(multiple_portfolios)
print(final_returns.to_string(index=False))
# Out:
# === 最終累積リターン ===
#                       Portfolio  Final Return
#  top_10p_compare_past_10_months          2.32
#   top_5p_compare_past_10_months          2.29
#  top_10p_compare_past_11_months          2.28
#   top_10p_compare_past_9_months          2.26
#  top_10p_compare_past_12_months          2.26
#   top_10p_compare_past_8_months          2.22
#   top_10p_compare_past_7_months          2.20
#    top_5p_compare_past_8_months          2.19
#   top_5p_compare_past_12_months          2.18
#   top_5p_compare_past_11_months          2.18
#  top_15p_compare_past_11_months          2.14
#   top_10p_compare_past_6_months          2.11
#  top_15p_compare_past_12_months          2.10
#    top_5p_compare_past_7_months          2.10
#  top_20p_compare_past_10_months          2.08
#  top_20p_compare_past_11_months          2.07
#   top_20p_compare_past_9_months          2.07
#   top_15p_compare_past_9_months          2.06
#  top_15p_compare_past_10_months          2.06
#   top_15p_compare_past_4_months          2.04
#  top_20p_compare_past_12_months          2.04
#    top_5p_compare_past_9_months          2.03
#   top_10p_compare_past_5_months          2.02
#  top_25p_compare_past_12_months          2.02
#  top_25p_compare_past_10_months          2.01
#   top_10p_compare_past_3_months          2.01
#   top_25p_compare_past_2_months          2.00
#   top_20p_compare_past_8_months          2.00
#   top_25p_compare_past_1_months          2.00
#   top_15p_compare_past_8_months          1.99
#   top_20p_compare_past_4_months          1.99
#   top_30p_compare_past_9_months          1.99
#  top_25p_compare_past_11_months          1.98
#   top_15p_compare_past_7_months          1.98
#   top_15p_compare_past_6_months          1.98
#   top_20p_compare_past_2_months          1.97
#  top_30p_compare_past_10_months          1.97
#   top_20p_compare_past_1_months          1.97
#   top_25p_compare_past_9_months          1.96
#  top_30p_compare_past_11_months          1.95
#   top_30p_compare_past_1_months          1.95
#   top_20p_compare_past_3_months          1.95
#   top_15p_compare_past_5_months          1.95
#   top_30p_compare_past_2_months          1.95
#   top_15p_compare_past_3_months          1.94
#  top_35p_compare_past_10_months          1.93
#   top_20p_compare_past_5_months          1.93
#   top_25p_compare_past_4_months          1.93
#   top_30p_compare_past_8_months          1.93
#  top_40p_compare_past_12_months          1.93
#   top_25p_compare_past_6_months          1.92
#   top_25p_compare_past_3_months          1.92
#  top_30p_compare_past_12_months          1.92
#   top_25p_compare_past_8_months          1.92
#  top_35p_compare_past_12_months          1.92
#   top_30p_compare_past_3_months          1.91
#   top_20p_compare_past_7_months          1.91
#  top_35p_compare_past_11_months          1.91
#   top_40p_compare_past_9_months          1.91
#   top_35p_compare_past_9_months          1.91
#   top_25p_compare_past_5_months          1.91
#   top_10p_compare_past_4_months          1.91
#  top_40p_compare_past_10_months          1.91
#   top_30p_compare_past_6_months          1.90
#   top_35p_compare_past_8_months          1.90
#   top_30p_compare_past_7_months          1.90
#  top_40p_compare_past_11_months          1.90
#   top_25p_compare_past_7_months          1.89
#   top_35p_compare_past_3_months          1.89
#    top_5p_compare_past_4_months          1.89
#  top_45p_compare_past_10_months          1.89
#    top_5p_compare_past_6_months          1.88
#   top_30p_compare_past_5_months          1.87
#  top_45p_compare_past_11_months          1.87
#  top_45p_compare_past_12_months          1.86
#   top_35p_compare_past_4_months          1.86
#   top_35p_compare_past_1_months          1.86
#   top_35p_compare_past_5_months          1.86
#   top_35p_compare_past_6_months          1.86
#   top_20p_compare_past_6_months          1.86
#   top_15p_compare_past_2_months          1.86
#   top_35p_compare_past_2_months          1.86
#   top_15p_compare_past_1_months          1.86
#   top_40p_compare_past_7_months          1.85
#   top_40p_compare_past_2_months          1.84
#   top_40p_compare_past_1_months          1.84
#   top_10p_compare_past_1_months          1.84
#   top_10p_compare_past_2_months          1.84
#   top_40p_compare_past_6_months          1.84
#   top_40p_compare_past_3_months          1.84
#  top_50p_compare_past_10_months          1.84
#   top_40p_compare_past_8_months          1.83
#  top_50p_compare_past_12_months          1.83
#   top_35p_compare_past_7_months          1.83
#   top_45p_compare_past_9_months          1.83
#  top_50p_compare_past_11_months          1.82
#   top_45p_compare_past_2_months          1.82
#   top_45p_compare_past_1_months          1.82
#    top_5p_compare_past_5_months          1.82
#   top_30p_compare_past_4_months          1.82
#   top_45p_compare_past_4_months          1.81
#   top_40p_compare_past_4_months          1.80
#   top_45p_compare_past_8_months          1.80
#   top_50p_compare_past_9_months          1.80
#  top_55p_compare_past_12_months          1.80
#    top_5p_compare_past_1_months          1.80
#    top_5p_compare_past_2_months          1.80
#   top_40p_compare_past_5_months          1.79
#   top_45p_compare_past_3_months          1.79
#   top_45p_compare_past_7_months          1.79
#   top_50p_compare_past_2_months          1.78
#   top_50p_compare_past_3_months          1.78
#   top_50p_compare_past_8_months          1.78
#  top_55p_compare_past_10_months          1.78
#   top_50p_compare_past_1_months          1.78
#   top_45p_compare_past_6_months          1.77
#   top_55p_compare_past_3_months          1.76
#   top_55p_compare_past_9_months          1.76
#   top_60p_compare_past_9_months          1.76
#   top_50p_compare_past_4_months          1.76
#  top_55p_compare_past_11_months          1.76
#   top_55p_compare_past_8_months          1.75
#   top_45p_compare_past_5_months          1.75
#  top_60p_compare_past_10_months          1.74
#   top_55p_compare_past_4_months          1.74
#   top_50p_compare_past_5_months          1.74
#   top_50p_compare_past_7_months          1.74
#  top_60p_compare_past_12_months          1.73
#  top_60p_compare_past_11_months          1.73
#   top_50p_compare_past_6_months          1.73
#   top_60p_compare_past_5_months          1.72
#   top_55p_compare_past_6_months          1.72
#   top_60p_compare_past_3_months          1.72
#   top_60p_compare_past_8_months          1.72
#   top_65p_compare_past_9_months          1.72
#   top_55p_compare_past_2_months          1.72
#   top_55p_compare_past_1_months          1.72
#  top_70p_compare_past_11_months          1.71
#   top_55p_compare_past_7_months          1.71
#  top_65p_compare_past_12_months          1.71
#   top_65p_compare_past_5_months          1.71
#  top_65p_compare_past_10_months          1.70
#  top_65p_compare_past_11_months          1.70
#  top_70p_compare_past_12_months          1.70
#   top_55p_compare_past_5_months          1.70
#   top_60p_compare_past_1_months          1.69
#   top_60p_compare_past_2_months          1.69
#   top_65p_compare_past_1_months          1.69
#   top_60p_compare_past_4_months          1.69
#  top_70p_compare_past_10_months          1.69
#   top_70p_compare_past_9_months          1.69
#   top_65p_compare_past_2_months          1.69
#   top_65p_compare_past_8_months          1.69
#   top_70p_compare_past_8_months          1.68
#  top_75p_compare_past_11_months          1.68
#   top_60p_compare_past_7_months          1.68
#  top_80p_compare_past_11_months          1.68
#   top_70p_compare_past_3_months          1.68
#   top_70p_compare_past_5_months          1.68
#  top_75p_compare_past_10_months          1.68
#   top_80p_compare_past_9_months          1.68
#   top_75p_compare_past_9_months          1.68
#   top_75p_compare_past_5_months          1.67
#   top_65p_compare_past_3_months          1.67
#   top_60p_compare_past_6_months          1.67
#   top_70p_compare_past_2_months          1.67
#   top_70p_compare_past_1_months          1.67
#   top_75p_compare_past_8_months          1.67
#   top_75p_compare_past_6_months          1.67
#  top_80p_compare_past_10_months          1.67
#  top_75p_compare_past_12_months          1.67
#  top_80p_compare_past_12_months          1.67
#   top_80p_compare_past_3_months          1.67
#   top_75p_compare_past_3_months          1.67
#   top_80p_compare_past_1_months          1.66
#   top_70p_compare_past_4_months          1.66
#   top_80p_compare_past_8_months          1.66
#   top_75p_compare_past_2_months          1.66
#   top_75p_compare_past_4_months          1.66
#   top_75p_compare_past_1_months          1.66
#   top_70p_compare_past_6_months          1.66
#   top_70p_compare_past_7_months          1.66
#   top_65p_compare_past_7_months          1.66
#   top_80p_compare_past_2_months          1.66
#   top_65p_compare_past_4_months          1.66
#   top_75p_compare_past_7_months          1.66
#   top_80p_compare_past_7_months          1.65
#   top_85p_compare_past_9_months          1.65
#   top_65p_compare_past_6_months          1.65
#   top_80p_compare_past_6_months          1.65
#   top_85p_compare_past_8_months          1.65
#  top_85p_compare_past_10_months          1.65
#   top_80p_compare_past_4_months          1.65
#   top_85p_compare_past_3_months          1.65
#    top_5p_compare_past_3_months          1.65
#   top_85p_compare_past_2_months          1.65
#   top_85p_compare_past_1_months          1.65
#   top_85p_compare_past_4_months          1.64
#   top_80p_compare_past_5_months          1.64
#  top_85p_compare_past_11_months          1.64
#   top_85p_compare_past_7_months          1.64
#   top_90p_compare_past_6_months          1.64
#   top_85p_compare_past_6_months          1.63
#   top_95p_compare_past_2_months          1.63
#   top_90p_compare_past_3_months          1.63
#   top_95p_compare_past_3_months          1.63
#   top_95p_compare_past_1_months          1.63
#   top_90p_compare_past_5_months          1.63
#  top_90p_compare_past_11_months          1.63
#  top_90p_compare_past_12_months          1.63
#   top_90p_compare_past_8_months          1.63
#  top_85p_compare_past_12_months          1.63
#  top_90p_compare_past_10_months          1.63
#   top_90p_compare_past_9_months          1.63
#   top_90p_compare_past_7_months          1.63
#   top_85p_compare_past_5_months          1.62
#  top_100p_compare_past_1_months          1.62
#   top_90p_compare_past_1_months          1.62
#  top_100p_compare_past_2_months          1.62
#  top_100p_compare_past_5_months          1.62
#  top_100p_compare_past_3_months          1.62
#   top_95p_compare_past_4_months          1.62
#  top_100p_compare_past_4_months          1.62
#   top_90p_compare_past_2_months          1.62
# top_100p_compare_past_11_months          1.62
#  top_100p_compare_past_9_months          1.62
# top_100p_compare_past_12_months          1.62
# top_100p_compare_past_10_months          1.62
#  top_100p_compare_past_7_months          1.62
#  top_100p_compare_past_6_months          1.62
#   top_95p_compare_past_7_months          1.62
#  top_100p_compare_past_8_months          1.62
#   top_95p_compare_past_9_months          1.62
#   top_90p_compare_past_4_months          1.61
#   top_95p_compare_past_5_months          1.61
#   top_95p_compare_past_6_months          1.61
#   top_95p_compare_past_8_months          1.61
#  top_95p_compare_past_10_months          1.61
#  top_95p_compare_past_11_months          1.61
#  top_95p_compare_past_12_months          1.61

# %%
# 分析結果サマリー
generate_analysis_summary(multiple_portfolios, df_yoy, performance_metrics)
# Out:
# === 分析結果サマリー ===
# 分析期間: 2020-08-01 00:00:00 から 2025-05-01 00:00:00
# 対象銘柄数: 275
# 分析したポートフォリオ: ['top_5p_compare_past_1_months', 'top_10p_compare_past_1_months', 'top_15p_compare_past_1_months', 'top_20p_compare_past_1_months', 'top_25p_compare_past_1_months', 'top_30p_compare_past_1_months', 'top_35p_compare_past_1_months', 'top_40p_compare_past_1_months', 'top_45p_compare_past_1_months', 'top_50p_compare_past_1_months', 'top_55p_compare_past_1_months', 'top_60p_compare_past_1_months', 'top_65p_compare_past_1_months', 'top_70p_compare_past_1_months', 'top_75p_compare_past_1_months', 'top_80p_compare_past_1_months', 'top_85p_compare_past_1_months', 'top_90p_compare_past_1_months', 'top_95p_compare_past_1_months', 'top_100p_compare_past_1_months', 'top_5p_compare_past_2_months', 'top_10p_compare_past_2_months', 'top_15p_compare_past_2_months', 'top_20p_compare_past_2_months', 'top_25p_compare_past_2_months', 'top_30p_compare_past_2_months', 'top_35p_compare_past_2_months', 'top_40p_compare_past_2_months', 'top_45p_compare_past_2_months', 'top_50p_compare_past_2_months', 'top_55p_compare_past_2_months', 'top_60p_compare_past_2_months', 'top_65p_compare_past_2_months', 'top_70p_compare_past_2_months', 'top_75p_compare_past_2_months', 'top_80p_compare_past_2_months', 'top_85p_compare_past_2_months', 'top_90p_compare_past_2_months', 'top_95p_compare_past_2_months', 'top_100p_compare_past_2_months', 'top_5p_compare_past_3_months', 'top_10p_compare_past_3_months', 'top_15p_compare_past_3_months', 'top_20p_compare_past_3_months', 'top_25p_compare_past_3_months', 'top_30p_compare_past_3_months', 'top_35p_compare_past_3_months', 'top_40p_compare_past_3_months', 'top_45p_compare_past_3_months', 'top_50p_compare_past_3_months', 'top_55p_compare_past_3_months', 'top_60p_compare_past_3_months', 'top_65p_compare_past_3_months', 'top_70p_compare_past_3_months', 'top_75p_compare_past_3_months', 'top_80p_compare_past_3_months', 'top_85p_compare_past_3_months', 'top_90p_compare_past_3_months', 'top_95p_compare_past_3_months', 'top_100p_compare_past_3_months', 'top_5p_compare_past_4_months', 'top_10p_compare_past_4_months', 'top_15p_compare_past_4_months', 'top_20p_compare_past_4_months', 'top_25p_compare_past_4_months', 'top_30p_compare_past_4_months', 'top_35p_compare_past_4_months', 'top_40p_compare_past_4_months', 'top_45p_compare_past_4_months', 'top_50p_compare_past_4_months', 'top_55p_compare_past_4_months', 'top_60p_compare_past_4_months', 'top_65p_compare_past_4_months', 'top_70p_compare_past_4_months', 'top_75p_compare_past_4_months', 'top_80p_compare_past_4_months', 'top_85p_compare_past_4_months', 'top_90p_compare_past_4_months', 'top_95p_compare_past_4_months', 'top_100p_compare_past_4_months', 'top_5p_compare_past_5_months', 'top_10p_compare_past_5_months', 'top_15p_compare_past_5_months', 'top_20p_compare_past_5_months', 'top_25p_compare_past_5_months', 'top_30p_compare_past_5_months', 'top_35p_compare_past_5_months', 'top_40p_compare_past_5_months', 'top_45p_compare_past_5_months', 'top_50p_compare_past_5_months', 'top_55p_compare_past_5_months', 'top_60p_compare_past_5_months', 'top_65p_compare_past_5_months', 'top_70p_compare_past_5_months', 'top_75p_compare_past_5_months', 'top_80p_compare_past_5_months', 'top_85p_compare_past_5_months', 'top_90p_compare_past_5_months', 'top_95p_compare_past_5_months', 'top_100p_compare_past_5_months', 'top_5p_compare_past_6_months', 'top_10p_compare_past_6_months', 'top_15p_compare_past_6_months', 'top_20p_compare_past_6_months', 'top_25p_compare_past_6_months', 'top_30p_compare_past_6_months', 'top_35p_compare_past_6_months', 'top_40p_compare_past_6_months', 'top_45p_compare_past_6_months', 'top_50p_compare_past_6_months', 'top_55p_compare_past_6_months', 'top_60p_compare_past_6_months', 'top_65p_compare_past_6_months', 'top_70p_compare_past_6_months', 'top_75p_compare_past_6_months', 'top_80p_compare_past_6_months', 'top_85p_compare_past_6_months', 'top_90p_compare_past_6_months', 'top_95p_compare_past_6_months', 'top_100p_compare_past_6_months', 'top_5p_compare_past_7_mon ...
#
# 最高パフォーマンス: top_10p_compare_past_10_months (131.50%)
# 最低パフォーマンス: top_95p_compare_past_12_months (60.59%)
#
# 最高シャープレシオ: top_25p_compare_past_12_months (2.12)
# 最低最大ドローダウン: top_5p_compare_past_12_months (-19.77%)
#
# === パーセンタイルポートフォリオ間の比較 ===
# 最高パーセンタイル: top_10p_compare_past_10_months (131.50%)
# 最低パーセンタイル: top_95p_compare_past_12_months (60.59%)
