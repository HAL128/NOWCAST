# %%
import pandas as pd
import numpy as np

# %%
# ファイルパス
file_path = '../data/CCA_sales_4-1_factor.csv'  # ここのファイルを変える以外は特に変更なし

df = pd.read_csv(file_path)

df.head()
# Out:
#       Date  Portfolio_Return  Market_Return  Risk_Free_Rate    SMB    HML
# 0  2021-02         -0.108379          0.027          -0.001 -0.011  0.082
# 1  2021-03          0.054022          0.060          -0.001  0.051  0.102
# 2  2021-04          0.016017         -0.031          -0.001 -0.016 -0.027
# 3  2021-05          0.047126          0.017          -0.001 -0.015  0.032
# 4  2021-06          0.008033          0.009          -0.001  0.028 -0.026

# %%
# portfolio returnカラムをdrop
df = df.drop('Portfolio_Return', axis=1)

df
# Out:
#        Date  Market_Return  Risk_Free_Rate    SMB    HML
# 0   2021-02          0.027          -0.001 -0.011  0.082
# 1   2021-03          0.060          -0.001  0.051  0.102
# 2   2021-04         -0.031          -0.001 -0.016 -0.027
# 3   2021-05          0.017          -0.001 -0.015  0.032
# 4   2021-06          0.009          -0.001  0.028 -0.026
# 5   2021-07         -0.019          -0.001 -0.002  0.026
# 6   2021-08          0.033          -0.001 -0.002 -0.027
# 7   2021-09          0.051          -0.001  0.002  0.036
# 8   2021-10         -0.022          -0.001  0.010  0.009
# 9   2021-11         -0.031          -0.002 -0.020 -0.029
# 10  2021-12          0.032          -0.001  0.008  0.081
# 11  2022-01         -0.048          -0.001 -0.050  0.149
# 12  2022-02         -0.001          -0.001  0.020  0.023
# 13  2022-03          0.038          -0.001  0.039  0.017
# 14  2022-04         -0.016          -0.002  0.062  0.120
# 15  2022-05         -0.008          -0.001 -0.022 -0.014
# 16  2022-06         -0.005          -0.001  0.082  0.100
# 17  2022-07          0.032          -0.001 -0.016 -0.079
# 18  2022-08          0.015          -0.001  0.057  0.052
# 19  2022-09         -0.051          -0.002  0.056  0.065
# 20  2022-10          0.049          -0.001  0.017 -0.006
# 21  2022-11          0.036          -0.002 -0.060 -0.059
# 22  2022-12         -0.040          -0.002 -0.038  0.020
# 23  2023-01          0.037          -0.002 -0.018 -0.029
# 24  2023-02          0.015          -0.002  0.052  0.101
# 25  2023-03          0.018          -0.002 -0.024 -0.061
# 26  2023-04          0.022          -0.002  0.003  0.052
# 27  2023-05          0.040          -0.002 -0.012  0.011
# 28  2023-06          0.078          -0.001  0.021  0.073
# 29  2023-07          0.011          -0.001 -0.025  0.036
# 30  2023-08          0.011          -0.003  0.033  0.062
# 31  2023-09         -0.000          -0.002  0.012  0.103
# 32  2023-10         -0.034          -0.002  0.002  0.034
# 33  2023-11          0.058          -0.001 -0.030 -0.069
# 34  2023-12          0.008          -0.001 -0.022 -0.053
# 35  2024-01          0.078          -0.002  0.011  0.087
# 36  2024-02          0.044          -0.001 -0.007  0.013
# 37  2024-03          0.044          -0.001 -0.000  0.063
# 38  2024-04         -0.021           0.000  0.021  0.086
# 39  2024-05          0.011           0.001 -0.009  0.024
# 40  2024-06          0.017           0.000  0.045  0.003
# 41  2024-07         -0.001           0.001 -0.062 -0.057
# 42  2024-08         -0.041           0.001 -0.029 -0.095

# %%
portfolio_data = pd.read_csv('../data/cca_compare_past_month.csv')
portfolio_data.head()
# Out:
#      MONTH  top_25p_compare_past_1_months  top_100p_compare_past_1_months  \
# 0  2019-07                       0.029629                        0.029629
# 1  2019-08                      -0.008580                       -0.008580
# 2  2019-09                       0.038782                        0.038782
# 3  2019-10                       0.017872                        0.017872
# 4  2019-11                       0.031689                        0.031689
#
#    top_25p_compare_past_2_months  top_100p_compare_past_2_months  \
# 0                       0.049217                        0.029629
# 1                      -0.011313                       -0.008580
# 2                       0.027373                        0.038782
# 3                       0.023959                        0.017872
# 4                       0.022210                        0.031689
#
#    top_25p_compare_past_3_months  top_100p_compare_past_3_months  \
# 0                       0.031221                        0.029629
# 1                      -0.003041                       -0.008580
# 2                       0.031236                        0.038782
# 3                       0.018695                        0.017872
# 4                       0.014305                        0.031689
#
#    top_25p_compare_past_4_months  top_100p_compare_past_4_months  \
# 0                       0.036063                        0.029629
# 1                       0.000061                       -0.008580
# 2                       0.034818                        0.038782
# 3                       0.023808                        0.017872
# 4                       0.021108                        0.031689
#
#    top_25p_compare_past_5_months  ...  top_25p_compare_past_8_months  \
# 0                       0.038455  ...                       0.047539
# 1                       0.000683  ...                      -0.008964
# 2                       0.035163  ...                       0.034145
# 3                       0.029384  ...                       0.019567
# 4                       0.016837  ...                       0.018415
#
#    top_100p_compare_past_8_months  top_25p_compare_past_9_months  \
# 0                        0.029629                       0.047339
# 1                       -0.008580                      -0.005311
# 2                        0.038782                       0.034861
# 3                        0.017872                       0.024004
# 4                        0.031689                       0.019201
#
#    top_100p_compare_past_9_months  top_25p_compare_past_10_months  \
# 0                        0.029629                        0.044882
# 1                       -0.008580                       -0.003654
# 2                        0.038782                        0.034663
# 3                        0.017872                        0.024051
# 4                        0.031689                        0.021886
#
#    top_100p_compare_past_10_months  top_25p_compare_past_11_months  \
# 0                         0.029629                        0.041772
# 1                        -0.008580                        0.000106
# 2                         0.038782                        0.038723
# 3                         0.017872                        0.017733
# 4                         0.031689                        0.022332
#
#    top_100p_compare_past_11_months  top_25p_compare_past_12_months  \
# 0                         0.029629                        0.042520
# 1                        -0.008580                        0.001214
# 2                         0.038782                        0.038723
# 3                         0.017872                        0.014954
# 4                         0.031689                        0.017507
#
#    top_100p_compare_past_12_months
# 0                         0.029629
# 1                        -0.008580
# 2                         0.038782
# 3                         0.017872
# 4                         0.031689
#
# [5 rows x 25 columns]

# %%
numeric_columns = portfolio_data.select_dtypes(include=[np.number]).columns.tolist()

#%%
# 各カラムの累積リターンを計算
cumulative_returns = {}

for col in numeric_columns:
    # NaNを除外してリターンを取得
    returns = portfolio_data[col].dropna()
    
    if len(returns) > 0:
        # 累積リターンを計算 (1 + r1) * (1 + r2) * ... - 1
        cumulative_return = (1 + returns).prod() - 1
        cumulative_returns[col] = cumulative_return
        print(f"{col}: {cumulative_return:.6f}")
    else:
        cumulative_returns[col] = np.nan
        print(f"{col}: データなし")

#%%
# 最大の累積リターンを特定
max_return = max(cumulative_returns.values())
max_return_column = max(cumulative_returns, key=cumulative_returns.get)

print(f"\n最大の累積リターン: {max_return:.6f}")
print(f"最大リターンを出したカラム: {max_return_column}")
# Out:
# top_25p_compare_past_1_months: 0.868825
# top_100p_compare_past_1_months: 0.868825
# top_25p_compare_past_2_months: 1.783047
# top_100p_compare_past_2_months: 0.868825
# top_25p_compare_past_3_months: 1.632617
# top_100p_compare_past_3_months: 0.868825
# top_25p_compare_past_4_months: 1.918464
# top_100p_compare_past_4_months: 0.868825
# top_25p_compare_past_5_months: 2.036018
# top_100p_compare_past_5_months: 0.868825
# top_25p_compare_past_6_months: 2.290263
# top_100p_compare_past_6_months: 0.868825
# top_25p_compare_past_7_months: 2.602539
# top_100p_compare_past_7_months: 0.868825
# top_25p_compare_past_8_months: 2.855815
# top_100p_compare_past_8_months: 0.868825
# top_25p_compare_past_9_months: 3.204523
# top_100p_compare_past_9_months: 0.868825
# top_25p_compare_past_10_months: 3.080131
# top_100p_compare_past_10_months: 0.868825
# top_25p_compare_past_11_months: 2.980548
# top_100p_compare_past_11_months: 0.868825
# top_25p_compare_past_12_months: 2.692550
# top_100p_compare_past_12_months: 0.868825
#
# 最大の累積リターン: 3.204523
# 最大リターンを出したカラム: top_25p_compare_past_9_months

# %%
# top_25p_compare_past_9_monthsカラム意外をdrop
portfolio_data = portfolio_data.drop(columns=['top_25p_compare_past_1_months', 'top_25p_compare_past_2_months', 'top_25p_compare_past_3_months', 'top_25p_compare_past_4_months', 'top_25p_compare_past_5_months', 'top_25p_compare_past_6_months', 'top_25p_compare_past_7_months', 'top_25p_compare_past_8_months', 'top_25p_compare_past_10_months', 'top_25p_compare_past_11_months', 'top_25p_compare_past_12_months', 'top_100p_compare_past_1_months', 'top_100p_compare_past_2_months', 'top_100p_compare_past_3_months', 'top_100p_compare_past_4_months', 'top_100p_compare_past_5_months', 'top_100p_compare_past_6_months', 'top_100p_compare_past_7_months', 'top_100p_compare_past_8_months', 'top_100p_compare_past_9_months', 'top_100p_compare_past_10_months', 'top_100p_compare_past_11_months', 'top_100p_compare_past_12_months'])
portfolio_data
# Out:
#       MONTH  top_25p_compare_past_9_months
# 0   2019-07                       0.047339
# 1   2019-08                      -0.005311
# 2   2019-09                       0.034861
# 3   2019-10                       0.024004
# 4   2019-11                       0.019201
# ..      ...                            ...
# 66  2025-01                       0.012859
# 67  2025-02                      -0.006279
# 68  2025-03                       0.025293
# 69  2025-04                       0.039572
# 70  2025-05                       0.024406
#
# [71 rows x 2 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
portfolio_data['MONTH'] = pd.to_datetime(portfolio_data['MONTH'])
# dateをキーにして結合
df = pd.merge(df, portfolio_data[['MONTH', 'top_25p_compare_past_9_months']], 
                      left_on='Date', right_on='MONTH', how='inner')
# 1. 'top_25p' を 'Portfolio_Return' にリネーム
df = df.rename(columns={'top_25p_compare_past_9_months




















fsjfjsfsff': 'Portfolio_Return'})

# 2. 'Date' 列を残し、'MONTH' 列を削除
# ただし、'Date'と'MONTH'の値が本当に同じか確認しておくと安全です
if (df['Date'] == df['MONTH']).all():
    df = df.drop(columns=['MONTH'])
else:
    print("Warning: 'Date'と'MONTH'の値が一致していません。")

# 3. 必要なら 'Date' 列の型を datetime に変換
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#          Date  Market_Return  Risk_Free_Rate    SMB    HML  Portfolio_Return
# 0  2021-02-01          0.027          -0.001 -0.011  0.082          0.096954
# 1  2021-03-01          0.060          -0.001  0.051  0.102          0.019360
# 2  2021-04-01         -0.031          -0.001 -0.016 -0.027         -0.023019
# 3  2021-05-01          0.017          -0.001 -0.015  0.032          0.058026
# 4  2021-06-01          0.009          -0.001  0.028 -0.026          0.044766
# 5  2021-07-01         -0.019          -0.001 -0.002  0.026         -0.030383
# 6  2021-08-01          0.033          -0.001 -0.002 -0.027          0.047991
# 7  2021-09-01          0.051          -0.001  0.002  0.036          0.051969
# 8  2021-10-01         -0.022          -0.001  0.010  0.009         -0.032409
# 9  2021-11-01         -0.031          -0.002 -0.020 -0.029         -0.028331
# 10 2021-12-01          0.032          -0.001  0.008  0.081          0.002083
# 11 2022-01-01         -0.048          -0.001 -0.050  0.149         -0.051387
# 12 2022-02-01         -0.001          -0.001  0.020  0.023          0.044146
# 13 2022-03-01          0.038          -0.001  0.039  0.017          0.028412
# 14 2022-04-01         -0.016          -0.002  0.062  0.120          0.000002
# 15 2022-05-01         -0.008          -0.001 -0.022 -0.014          0.028905
# 16 2022-06-01         -0.005          -0.001  0.082  0.100          0.012927
# 17 2022-07-01          0.032          -0.001 -0.016 -0.079          0.025011
# 18 2022-08-01          0.015          -0.001  0.057  0.052          0.040929
# 19 2022-09-01         -0.051          -0.002  0.056  0.065          0.001110
# 20 2022-10-01          0.049          -0.001  0.017 -0.006          0.030768
# 21 2022-11-01          0.036          -0.002 -0.060 -0.059          0.041520
# 22 2022-12-01         -0.040          -0.002 -0.038  0.020         -0.005930
# 23 2023-01-01          0.037          -0.002 -0.018 -0.029          0.037596
# 24 2023-02-01          0.015          -0.002  0.052  0.101          0.002829
# 25 2023-03-01          0.018          -0.002 -0.024 -0.061          0.014102
# 26 2023-04-01          0.022          -0.002  0.003  0.052          0.039003
# 27 2023-05-01          0.040          -0.002 -0.012  0.011         -0.014550
# 28 2023-06-01          0.078          -0.001  0.021  0.073          0.042132
# 29 2023-07-01          0.011          -0.001 -0.025  0.036          0.014524
# 30 2023-08-01          0.011          -0.003  0.033  0.062          0.050127
# 31 2023-09-01         -0.000          -0.002  0.012  0.103         -0.017637
# 32 2023-10-01         -0.034          -0.002  0.002  0.034         -0.012415
# 33 2023-11-01          0.058          -0.001 -0.030 -0.069          0.035633
# 34 2023-12-01          0.008          -0.001 -0.022 -0.053          0.024021
# 35 2024-01-01          0.078          -0.002  0.011  0.087          0.037354
# 36 2024-02-01          0.044          -0.001 -0.007  0.013          0.000182
# 37 2024-03-01          0.044          -0.001 -0.000  0.063          0.042303
# 38 2024-04-01         -0.021           0.000  0.021  0.086         -0.013614
# 39 2024-05-01          0.011           0.001 -0.009  0.024         -0.011370
# 40 2024-06-01          0.017           0.000  0.045  0.003          0.026732
# 41 2024-07-01         -0.001           0.001 -0.062 -0.057          0.020309
# 42 2024-08-01         -0.041           0.001 -0.029 -0.095          0.018647

# %%
# 適切なカラム名を使用して日付をインデックスに設定
# ここでは仮に 'Date' というカラム名が日付を表していると仮定します
df['Date'] = pd.to_datetime(df['Date'])  # 'Date' を実際のカラム名に置き換えてください
df.set_index('Date', inplace=True)

# 超過リターンの計算
excess_return = df['Portfolio_Return'] - df['Risk_Free_Rate']

# 回帰分析の結果を格納するリスト
alpha_values = []
factor_values = {'Market': [], 'SMB': [], 'HML': []}

# 12か月ローリングウインドウで回帰分析
window_size = 12
for start in range(len(df) - window_size + 1):
    end = start + window_size
    window_data = df.iloc[start:end]
    X = window_data[['Market_Return', 'SMB', 'HML']].values
    y = excess_return[start:end].values
    X = np.column_stack((np.ones(X.shape[0]), X))  # 定数項を追加
    beta = np.linalg.inv(X.T @ X) @ X.T @ y
    alpha_values.append(beta[0])
    factor_values['Market'].append(beta[1])
    factor_values['SMB'].append(beta[2])
    factor_values['HML'].append(beta[3])

# 結果をデータフレームに変換
results_df = pd.DataFrame({
    'Alpha': alpha_values,
    'Market': factor_values['Market'],
    'SMB': factor_values['SMB'],
    'HML': factor_values['HML']
}, index=df.index[window_size-1:])

# 結果を表示
print(results_df.head())

import matplotlib.pyplot as plt

# プロットのサイズを設定
plt.figure(figsize=(12, 10))

# アルファ（切片）の時系列プロット
plt.subplot(4, 1, 1)
plt.plot(results_df.index, results_df['Alpha'], marker='o', label='Alpha')
plt.title('Alpha over Time')
plt.ylabel('Alpha')
plt.legend()

# マーケットファクターの係数の時系列プロット
plt.subplot(4, 1, 2)
plt.plot(results_df.index, results_df['Market'], marker='o', color='red', label='Market')
plt.title('Market Factor Beta over Time')
plt.ylabel('Market Beta')
plt.legend()

# SMB ファクターの係数の時系列プロット
plt.subplot(4, 1, 3)
plt.plot(results_df.index, results_df['SMB'], marker='o', color='green', label='SMB')
plt.title('SMB Factor Beta over Time')
plt.ylabel('SMB Beta')
plt.legend()

# HML ファクターの係数の時系列プロット
plt.subplot(4, 1, 4)
plt.plot(results_df.index, results_df['HML'], marker='o', color='blue', label='HML')
plt.title('HML Factor Beta over Time')
plt.xlabel('Date')
plt.ylabel('HML Beta')
plt.legend()

plt.tight_layout()  # 各プロットの間隔を自動調整
plt.show()
# Out:
#                Alpha    Market       SMB       HML
# Date
# 2022-01-01  0.010575  1.423051 -0.834446 -0.204570
# 2022-02-01  0.012806  1.024428 -0.242419 -0.245509
# 2022-03-01  0.011795  1.032133 -0.100928 -0.171891
# 2022-04-01  0.012254  0.903141  0.133501 -0.116011
# 2022-05-01  0.012723  0.780515  0.187423 -0.166147
